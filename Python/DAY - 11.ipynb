# %%
import pandas as pd

# %%
df = pd.read_csv("Order_Delivery_Performance_Dataset (2).csv")

# %%
df.head()
# Out:
#     Order_ID Customer_ID  Order_Date  Processing_Time_Hours Shipping_Date  \
# 0  ORD000001   CUST02195  2025-06-15                     20    15-06-2025
# 1  ORD000002   CUST00243  2025-08-03                      9    03-08-2025
# 2  ORD000003   CUST01187  2025-01-26                     29    27-01-2025
# 3  ORD000004   CUST02312  2025-02-22                     25    23-02-2025
# 4  ORD000005   CUST02864  2025-10-27                     59    29-10-2025
#
#   Expected_Delivery_Date Actual_Delivery_Date  Delivery_Time_Days  \
# 0             20-06-2025           20-06-2025                 5.0
# 1             06-08-2025           13-08-2025                10.0
# 2             29-01-2025           29-01-2025                 2.0
# 3             27-02-2025           01-03-2025                 6.0
# 4             02-11-2025           02-11-2025                 4.0
#
#   Delivery_Status  Delay_Days  ... Cancellation_Reason       Courier  \
# 0         On Time         0.0  ...    Customer Request           DHL
# 1         Delayed         7.0  ...    Customer Request  Ecom Express
# 2         On Time         0.0  ...    Customer Request      BlueDart
# 3         Delayed         2.0  ...    Customer Request           DHL
# 4         On Time         0.0  ...    Customer Request  Ecom Express
#
#   Warehouse   Region Shipping_Cost  Order_Value  Customer_Rating  \
# 0     WH-03  Central            79        33455                2
# 1     WH-05    North           164        41528                5
# 2     WH-02  Central           110        37615                3
# 3     WH-05    South           304        44790                5
# 4     WH-02    North           344        19877                5
#
#    Payment_Method Product_Category  Priority
# 0             UPI      Electronics   Express
# 1             UPI           Beauty   Express
# 2     Net Banking           Sports  Standard
# 3             COD             Home   Express
# 4             COD             Home   Express
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                10000 non-null  object
#  1   Customer_ID             10000 non-null  object
#  2   Order_Date              10000 non-null  object
#  3   Processing_Time_Hours   10000 non-null  int64
#  4   Shipping_Date           10000 non-null  object
#  5   Expected_Delivery_Date  10000 non-null  object
#  6   Actual_Delivery_Date    10000 non-null  object
#  7   Delivery_Time_Days      10000 non-null  float64
#  8   Delivery_Status         10000 non-null  object
#  9   Delay_Days              10000 non-null  float64
#  10  Cancellation            10000 non-null  object
#  11  Cancellation_Reason     10000 non-null  object
#  12  Courier                 10000 non-null  object
#  13  Warehouse               10000 non-null  object
#  14  Region                  10000 non-null  object
#  15  Shipping_Cost           10000 non-null  int64
#  16  Order_Value             10000 non-null  int64
#  17  Customer_Rating         10000 non-null  int64
#  18  Payment_Method          10000 non-null  object
#  19  Product_Category        10000 non-null  object
#  20  Priority                10000 non-null  object
# dtypes: float64(2), int64(4), object(15)
# memory usage: 1.6+ MB

# %%
print("Missing values before cleaning")
df.isnull().sum()
# Out:
# Missing values before cleaning
# Order_ID                  0
# Customer_ID               0
# Order_Date                0
# Processing_Time_Hours     0
# Shipping_Date             0
# Expected_Delivery_Date    0
# Actual_Delivery_Date      0
# Delivery_Time_Days        0
# Delivery_Status           0
# Delay_Days                0
# Cancellation              0
# Cancellation_Reason       0
# Courier                   0
# Warehouse                 0
# Region                    0
# Shipping_Cost             0
# Order_Value               0
# Customer_Rating           0
# Payment_Method            0
# Product_Category          0
# Priority                  0
# dtype: int64

# %%
rows_before = len(df)

df = df.drop_duplicates()

rows_after = len(df)

print("Rows Before:", rows_before)
print("Rows After :", rows_after)
print("Duplicates Removed:", rows_before - rows_after)
# Out:
# Rows Before: 10000
# Rows After : 10000
# Duplicates Removed: 0
